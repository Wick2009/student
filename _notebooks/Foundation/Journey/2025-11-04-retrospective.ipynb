# %% [markdown]
# # Retrospective — 2025-11-04
#
# A short retrospective capturing recent progress, learnings, and next steps.

# %% [markdown]
# ## What I worked on
#
# - Completed and debugged several homework notebooks (strings, lists, algorithms, procedures, random values, algorithmic-efficiency).
# - Fixed image paths so charts render correctly.
# - Replaced escaped emoji sequences and normalized YAML front-matter to avoid conversion errors.

# %% [markdown]
# ## What I learned
#
# - YAML front-matter and illegal surrogate escapes can break notebook-to-markdown conversion; use plain ASCII titles or proper UTF-8 characters.
# - Small algorithmic changes (precomputation, reducing inner-loop work) significantly improve complexity.

# %% [markdown]
# ## Challenges
#
# - Some notebooks contained escaped Unicode sequences that caused write/encode errors during conversion.
# - Large vendor files (venv / JS source maps) contain many `\u` sequences but are safe to ignore for content fixes.

# %% [markdown]
# ## Next steps
#
# 1. Re-run the notebook → markdown conversion (site build) and paste any error output here if it fails.
# 2. Run edited notebooks to validate runtime outputs.
# 3. If you want, I can run the conversion and/or execute notebooks for a quick smoke test.

# %%
# Quick verification cell
print('Retrospective (2025-11-04) restored. Edit as needed.')
