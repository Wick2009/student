# %% [markdown]
# ---
# layout: post
# toc: True
# breadcrumb: True
# title: My Journey
# description: These Programming topics are focused on Jupyter Notebooks, and Managing Files.
# permalink: /blog
# author: Sathwik Kintada
# ---

# %% [markdown]
# # My CSP Setup and Workflow Journey
# ---
# ## Installing VS Code and Extensions
# I installed VS Code from the official site and made sure to add it to PATH for easy access. I also enabled context menu options to open folders quickly.
#
# ### Extensions Installed
# - Python (Microsoft) for coding and debugging
# - Jupyter (Microsoft) for working with notebooks
# - GitLens for advanced Git features
#
# ### Verifying Installations
# I used the terminal to check my Python and Git installations:

# %% [markdown]
# # MacOS Operating System and Tools Setup
# This guide walks through setting up developer tools on MacOS, including Homebrew, Python, VS Code, and more.

# %% [markdown]
# ## Visual Representation of the Workflow
# 💻 Open Terminal and use Linux/MacOS commands:
# - `mkdir`, `cd`, `ls` to manage folders
# 📁 Clone Project:
# - `git clone https://...`
# 🛠️ Activate Tools:
# - Ruby, Python, Git
# 🔄 SDLC:
# - `code` → `make` → `test` → `commit`
# ---
# ## Shell Commands Overview
# Standard Unix shell commands for MacOS:
# - `ls`, `pwd`, `mkdir`, `cd`, `git`, `cat`

# %% [markdown]
# ---
# ## Version Control Commands
# - `git clone`: Make a working copy of a git repository from the cloud to your local machine.
# - `git pull`: Update your local copy of the repository with changes from the cloud repository.
# - `git commit`: Save changes to files in your local repository.
# - `git push`: Send updates from your local repository to the remote repository.

# %% [markdown]
# ---
# ## Package Manager Commands – MacOS (brew)
# - List installed packages: `brew list`
# - Search for a package: `brew search <package_name>`
# - Update Homebrew: `brew update`
# - Upgrade installed packages: `brew upgrade`
# - Uninstall a package: `brew uninstall <package_name>`

# %% [markdown]
# ---
# ## MacOS Setup Steps
# 1. Install Homebrew
# 2. Install VS Code
# 3. First-time Setup (run commands in Terminal)

# %%
# Install Homebrew (run in MacOS Terminal)
# !/bin/bash -c "$(curl -fsSL https://raw.githubusercontent.com/Homebrew/install/HEAD/install.sh)"

# %%
# Install VS Code (run in MacOS Terminal)
# !brew install --cask visual-studio-code

# %%
# First-time setup (run each line in MacOS Terminal)
# !mkdir opencs
# !cd opencs
# !git clone https://github.com/Open-Coding-Society/student.git
# !cd student/
# !./scripts/activate_macos.sh
# !./scripts/activate.sh # prompts for Git UID and Personal Email
# !./scripts/venv.sh

# %% [markdown]
# ---
# ## Setup Checks (Optional)
# You can always come back to these checks later if your tools stop working.
# - `python --version`
# - `pip --version`
# - `ruby -v`
# - `bundle -v`
# - `gem --version`
# - `git config --global --list`
#
# ## Starting a session to work in VSCode
# Each time you open a new Terminal to work, run:
# - `cd opencs/student`
# - `source venv/bin/activate` # activate Python virtual environment
# - `code .`

# %% [markdown]
# ---
# ## Managing Repositories and Personalizing My Site
# - Cloned the main pages repository into my opencs folder.
# - Experimented with themes and made personal changes to my site.
# - Created my own student repository for personal work.

# %% [markdown]
# ---
# ## Setting Up a Python Virtual Environment
# I used a setup script to create a Python virtual environment for my project. This helps keep dependencies organized and separate from the system Python.

# %%
# Setup virtual environment
# !./scripts/venv.sh

# Activate the virtual environment (run in terminal, not notebook)
# !source venv/bin/activate

# %% [markdown]
# ---
# ## Collaborating with My Team
# I created and forked shared repositories for team projects, making it easier to work together and contribute to group assignments.

# %% [markdown]
# ---
# ## Working with Jupyter Notebooks
# I located and opened notebook files in VS Code, ran cells, and edited code and outputs to personalize my notebooks (like adding my own jokes!).

# %%
# Commit notebook with outputs
# !git add <notebook_filename>.ipynb
# !git commit -m "Updated notebook with outputs"
# !git push

# %% [markdown]
# ---
# ## Other Accomplishments
# - Verified notebook outputs appeared correctly on my site.
# - Ensured Python code ran smoothly in the virtual environment.
# - Managed multiple repositories and customized project settings.
# - Got VS Code working perfectly!

# %% [markdown]
# ---
# ## Reflections and Next Steps
# This process helped me learn a lot about coding, collaboration, and troubleshooting. I’m grateful for my peers who supported me along the way!
#
# ### Progress Weeks 1-4 Highlights
# - Created an About Me page
# - Cloned and managed multiple repositories
# - Learned to copy files between repos
# - Practiced with Jupyter Notebooks and added my own jokes
# - Changed the background image by editing `background.md`
#
# ---
# ## Upcoming: API Key Hack
# Next, I plan to work on the API key hack to add new features and learn more about integrating APIs into my projects. Stay tuned for updates!
